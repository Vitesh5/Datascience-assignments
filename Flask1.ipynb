# %%
#1
#Flask is a lightweight and flexible Python web framework. It's designed to be: Minimalistic:Provides the core components for web development without enforcing rigid structures or conventions.
#Advantages of Flask:Flexibility:Customize and extend functionality as needed, making it suitable for various web projects, from simple websites to complex web applications.
#Ease of use:Quickly get started and build prototypes without extensive configuration or boilerplate code.

# %%
#2

# %% [markdown]
# ![Screenshot 2024-01-07 124746.png](attachment:b8a75d30-4a6a-4e3b-8387-44203821ff06.png)

# %%
#3 App routing is the mechanism that maps URLs (Uniform Resource Locators) to specific Python functions within a Flask application.
# we use app routing to Organizing Application Logic,Handling Different Request Types,Creating Reusable Components,Mapping URLs to Content

# %%
#4

# %% [markdown]
# ![Screenshot 2024-01-07 125649.png](attachment:c823b6a8-4f66-4359-875a-9b8ed03e6928.png)

# %% [markdown]
# ![Screenshot 2024-01-07 125613.png](attachment:2b04546e-10cc-4f20-893f-0a67ca8bd134.png)

# %%
#5 The function used in Flask for URL building is url_for(). This function generates a URL for a given endpoint with the ability to pass additional arguments


from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Home Page'

@app.route('/user/<username>')
def profile(username):
    return '{}\'s profile'.format(username)

with app.test_request_context():
    print(url_for('home'))
    print(url_for('profile', username='John Doe'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       1 #5 The function used in Flask for URL building is url_for(). This function generates a URL for a given endpoint with the ability to pass additional arguments
# ----> 4 from flask import Flask, url_for
#       6 app = Flask(__name__)
#       8 @app.route('/')
#       9 def home():
#
# ModuleNotFoundError: No module named 'flask'
