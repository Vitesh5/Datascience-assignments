# %%
#1 GET: 
#Purpose: Used to retrieve data from a specified resource.
#Data Transmission: Appends query parameters to the URL to send data to the server.
#POST:
#Purpose: Used to submit data to a server to create or update a resource.
#Data Transmission: Includes data in the request body, not visible in the URL.

# %%
#2 
#The request object in Flask plays a crucial role in handling incoming web requests and interacting with client-side data.
# Its important because Accessing Request Information,Reading Request Data,Managing Session

# %%
#3 
#The redirect() function is used in Flask to instruct the user's browser to navigate to a different URL.

#it is used because it has sever important purposes  User Navigation, access control, error handling

# %%
#4 Templates are files containing static content (HTML, CSS, JavaScript) and placeholders for dynamic data. They serve as blueprint for web pages.
#render_template() function:This function is used to render a template and return the generated HTML content as a response to a web request.
 # Purpose: It bridges the gap between Python code and HTML templates, enabling the creation of dynamic and data-driven web pages.

# %%
#5

# %% [markdown]
# ![Screenshot 2024-01-07 142545.png](attachment:0418f3c3-499d-4326-978e-d27cbb357a61.png)
